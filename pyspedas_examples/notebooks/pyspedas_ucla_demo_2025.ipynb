# %% [markdown]
# The following line installs pyspedas in the current environment.  It is necessary for Google Colab.

# %%
# !pip install pyspedas
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Basic PySPEDAS example: Import necessary modules, load THEMIS FGM data for probe THEMIS-A, for time range 2007-03-23 to 2007-03-24, print a list of tplot variables, and plot two of them.

# %%
import pyspedas
from pyspedas import tplot_names, get_data, tplot

pyspedas.projects.themis.fgm(trange=['2007-03-23','2007-03-24'], probe='a')
tplot_names()
tplot(['tha_fgs_dsl', 'tha_fgl_dsl'])
# Out:
# 08-Jan-25 21:05:40: Downloading remote index: https://themis.ssl.berkeley.edu/data/themis/tha/l2/fgm/2007/
# 08-Jan-25 21:05:43: File is current: themis_data/tha/l2/fgm/2007/tha_l2_fgm_20070323_v01.cdf
# 0 : tha_fgs_btotal
# 1 : tha_fgs_gse
# 2 : tha_fgs_gsm
# 3 : tha_fgs_dsl
# 4 : tha_fgl_btotal
# 5 : tha_fgl_gse
# 6 : tha_fgl_gsm
# 7 : tha_fgl_dsl
# 8 : tha_fgl_ssl
# 9 : tha_fgh_btotal
# 10 : tha_fgh_gse
# 11 : tha_fgh_gsm
# 12 : tha_fgh_dsl
# 13 : tha_fgh_ssl
# 14 : tha_fge_btotal
# 15 : tha_fge_gse
# 16 : tha_fge_gsm
# 17 : tha_fge_dsl
# 18 : tha_fge_ssl

# %% [markdown]
# Examine the data and metadata for one of the tplot variables just loaded

# %%
data_arrays = get_data('tha_fgs_dsl')
print("Structure returned by get_data()", data_arrays)
data_times=data_arrays.times
data_vals=data_arrays.y
print("Data times",data_times)
print("Data values",data_vals)
# Out:
# Structure returned by get_data() variable(times=array([1.17460840e+09, 1.17460840e+09, 1.17460840e+09, ...,
#        1.17469467e+09, 1.17469467e+09, 1.17469467e+09]), y=array([[ 16.50905  ,  -8.597386 ,  14.1494465],
#        [ 16.497149 ,  -8.618044 ,  14.173288 ],
#        [ 16.53812  ,  -8.73796  ,  14.173288 ],
#        ...,
#        [ 17.318203 , -39.47606  ,  31.072771 ],
#        [ 18.690683 , -39.38634  ,  30.977404 ],
#        [ 18.59546  , -39.551605 ,  31.764185 ]], dtype=float32), v=array([1, 2, 3], dtype=int32))
# Data times [1.17460840e+09 1.17460840e+09 1.17460840e+09 ... 1.17469467e+09
#  1.17469467e+09 1.17469467e+09]
# Data values [[ 16.50905    -8.597386   14.1494465]
#  [ 16.497149   -8.618044   14.173288 ]
#  [ 16.53812    -8.73796    14.173288 ]
#  ...
#  [ 17.318203  -39.47606    31.072771 ]
#  [ 18.690683  -39.38634    30.977404 ]
#  [ 18.59546   -39.551605   31.764185 ]]

# %% [markdown]
# Extract the metadata from the same tplot variable

# %%
md=get_data('tha_fgs_dsl',metadata=True)
print("Metadata structure:")
print(md)
print("")
print("Metadata CDF.LABELS entries:", md["CDF"]["LABELS"])
print("")
print("Metadata data_att entries:", md["data_att"])
print("")
print("Metadata plot_options entries:",md["plot_options"])
# Out:
# Metadata structure:
# ...

# %% [markdown]
# Load and plot MMS FGM data

# %%
mms_tplot_vars = pyspedas.projects.mms.fgm(probe=[1,2],trange=['2015-10-16','2015-10-17'])
print(mms_tplot_vars)
tplot('mms2_fgm_b_gsm_srvy_l2_bvec')
# Out:
# 08-Jan-25 21:05:52: Loading pydata/mms1/fgm/srvy/l2/2015/10/mms1_fgm_srvy_l2_20151016_v4.18.0.cdf
# 08-Jan-25 21:05:54: Loading pydata/mms2/fgm/srvy/l2/2015/10/mms2_fgm_srvy_l2_20151016_v4.18.0.cdf
# ...

# %% [markdown]
# Load and plot MMS FEEPS spectrogram data

# %%
pyspedas.projects.mms.feeps(probe='1', trange=['2015-10-16','2015-10-17'],datatype='electron')
tplot(['mms1_epd_feeps_srvy_l2_electron_intensity_omni','mms1_epd_feeps_srvy_l2_electron_intensity_omni_spin'])
# Out:
# 08-Jan-25 21:06:05: Loading pydata/mms1/feeps/srvy/l2/electron/2015/10/mms1_feeps_srvy_l2_electron_20151016000000_v7.1.2.cdf
# 08-Jan-25 21:06:05: Integer data values for variable mms1_epd_feeps_srvy_l2_electron_top_quality_indicator_sensorid_1 are all fillval (-2147483648).
# 08-Jan-25 21:06:05: Integer data values for variable mms1_epd_feeps_srvy_l2_electron_top_quality_indicator_sensorid_2 are all fillval (-2147483648).
# 08-Jan-25 21:06:05: Integer data values for variable mms1_epd_feeps_srvy_l2_electron_top_quality_indicator_sensorid_9 are all fillval (-2147483648).
# 08-Jan-25 21:06:05: Integer data values for variable mms1_epd_feeps_srvy_l2_electron_top_quality_indicator_sensorid_10 are all fillval (-2147483648).
# 08-Jan-25 21:06:05: Integer data values for variable mms1_epd_feeps_srvy_l2_electron_bottom_quality_indicator_sensorid_1 are all fillval (-2147483648).
# ...

# %% [markdown]
# Perform some coordinate transforms on previously loaded THEMIS FGM data

# %%
from pyspedas.projects.themis import dsl2gse

dsl2gse('tha_fgl_dsl',name_out='tha_fgl_gse')
pyspedas.cotrans('tha_fgl_gse',coord_out='GEI',name_out='tha_fgl_gei')
pyspedas.cotrans('tha_fgl_gse',coord_out='GSM',name_out='tha_fgl_gsm')
tplot(['tha_fgl_dsl','tha_fgl_gse','tha_fgl_gei','tha_fgl_gsm'])
# Out:
# 08-Jan-25 21:06:08: File is current: themis_data/tha/l1/state/2007/tha_l1_state_20070323.cdf
# 08-Jan-25 21:06:08: Creating spin model for probe a correction level 0
# 08-Jan-25 21:06:08: FGM correction variables not available
# 08-Jan-25 21:06:08: Skipping FGM corrections, do_fgm_corr False, correction_level = 0
# 08-Jan-25 21:06:08: Creating spin model for probe a correction level 1
# 08-Jan-25 21:06:08: FGM correction variables not available
# 08-Jan-25 21:06:08: Skipping FGM corrections, do_fgm_corr False, correction_level = 1
# 08-Jan-25 21:06:08: Creating spin model for probe a correction level 2
# 08-Jan-25 21:06:08: FGM correction variables not available
# 08-Jan-25 21:06:08: Skipping FGM corrections, do_fgm_corr False, correction_level = 2
# 08-Jan-25 21:06:08: tinterpol (linear) was applied to: tha_spinras_corrected_hires
# 08-Jan-25 21:06:08: tinterpol (linear) was applied to: tha_spindec_corrected_hires
# 08-Jan-25 21:06:09: Running transformation: subgei2gse
# ...
