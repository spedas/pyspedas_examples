# %% [markdown]
# This notebook shows how to create 2D slices of 3D particle data from MMS FPI and HPCA using PySPEDAS

# %%
# !pip install pyspedas
# Out:
# Requirement already satisfied: pyspedas in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (2.0.5)
# Requirement already satisfied: numpy>=1.20.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2.2.6)
# Requirement already satisfied: requests>=2.31.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2.32.5)
# Requirement already satisfied: geopack>=1.0.12 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.0.12)
# Requirement already satisfied: scipy>=1.11.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.16.3)
# Requirement already satisfied: cdflib>=1.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.3.6)
# Requirement already satisfied: spacepy>=0.5.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (0.7.0)
# Requirement already satisfied: cdasws>=1.7.24 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.8.11)
# Requirement already satisfied: netCDF4>=1.6.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.7.3)
# Requirement already satisfied: pywavelets>=1.4.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.9.0)
# Requirement already satisfied: astropy>=5.3.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (7.1.1)
# Requirement already satisfied: hapiclient>=0.2.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (0.2.6)
# Requirement already satisfied: fsspec>=2023.9.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2025.10.0)
# Requirement already satisfied: s3fs>=2023.9.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2025.10.0)
# Requirement already satisfied: aioboto3>=11.1.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (15.5.0)
# Requirement already satisfied: pandas>=2.0.3 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2.3.3)
# Requirement already satisfied: matplotlib>=3.6.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (3.10.7)
# Requirement already satisfied: xarray>=2023.7.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2025.10.1)
# Requirement already satisfied: aiobotocore[boto3]==2.25.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aioboto3>=11.1.1->pyspedas) (2.25.1)
# Requirement already satisfied: aiofiles>=23.2.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aioboto3>=11.1.1->pyspedas) (25.1.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (0.13.0)
# Requirement already satisfied: botocore<1.40.62,>=1.40.46 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.40.61)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.17.3)
# Requirement already satisfied: boto3<1.40.62,>=1.40.46 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.40.61)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (0.2025.11.10.0.38.31)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (25.0)
# Requirement already satisfied: urllib3>=1.24.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from cdasws>=1.7.24->pyspedas) (2.5.0)
# Requirement already satisfied: isodate>=0.6.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from hapiclient>=0.2.2->pyspedas) (0.7.2)
# Requirement already satisfied: joblib in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from hapiclient>=0.2.2->pyspedas) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (3.2.5)
# Requirement already satisfied: cftime in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from netCDF4>=1.6.2->pyspedas) (1.6.4)
# Requirement already satisfied: certifi in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from netCDF4>=1.6.2->pyspedas) (2025.11.12)
# Requirement already satisfied: pytz>=2020.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pandas>=2.0.3->pyspedas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pandas>=2.0.3->pyspedas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from requests>=2.31.0->pyspedas) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from requests>=2.31.0->pyspedas) (3.11)
# Requirement already satisfied: h5py>=2.10 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from spacepy>=0.5.0->pyspedas) (3.15.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (4.15.0)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from boto3<1.40.62,>=1.40.46->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (0.14.0)

# %%
import pyspedas
from pyspedas.projects.mms import mms_part_slice2d

# %% [markdown]
# # Fast ion flows observed by the MMS FPI and HPCA instruments during a dayside reconnection event on March 24, 2023

# %%
time = '2023-03-24/07:07:33'

# %% [markdown]
# ## FPI ions with geometric interpolation
#
# The data are rotated such that the x axis is parallel to B field and the bulk velocity defines the x-y plane, and plotted using geometric interpolation (each point on the plot is given the value of the bin it intersects)

# %%
mms_part_slice2d(time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])
# Out:
# 18-Dec-25 14:35:32: Downloading mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf to pydata/mms1/fpi/brst/l2/dis-dist/2023/03/24
# 18-Dec-25 14:35:45: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-dist, after sorting and filtering:
# 18-Dec-25 14:35:45: pydata/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:35:46: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:35:46: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:35:46: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:35:46: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:35:46: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:35:46: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:35:46: The name mms1_dis_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:35:46: The name mms1_dis_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:35:46: Problem reading the variable: mms1_dis_compressionloss_brst_moms
# 18-Dec-25 14:35:46: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:35:46: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:35:46: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:35:46: Downloading mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf to pydata/mms1/fgm/brst/l2/2023/03/24
# 18-Dec-25 14:35:47: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:35:47: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:35:47: Downloading mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf to pydata/mms1/fpi/brst/l2/dis-moms/2023/03/24
# 18-Dec-25 14:35:48: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-moms, after sorting and filtering:
# 18-Dec-25 14:35:48: pydata/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:35:48: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:35:48: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:35:48: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:35:48: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:35:48: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:35:48: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:35:48: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:35:48: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:35:48: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:35:48: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:35:48: Averaging mms1_dis_bulkv_gse_brst
# 18-Dec-25 14:35:48: Aligning slice plane to: bv
# 18-Dec-25 14:35:50: Finished slice at 2023-03-24 07:07:32.858868

# %% [markdown]
# Return the slice data structure (instead of plotting) by setting the `return_slice` keyword to `True`

# %%
the_slice = mms_part_slice2d(return_slice=True, time=time, instrument='fpi', species='i', rotation='bv', erange=[0, 20000])
# Out:
# 18-Dec-25 14:35:51: Downloading mms1_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-dist/2023/03
# 18-Dec-25 14:36:14: Loading files for group: probe: 1, drate: fast, level: l2, datatype: dis-dist, after sorting and filtering:
# 18-Dec-25 14:36:14: pydata/mms1/fpi/fast/l2/dis-dist/2023/03/mms1_fpi_fast_l2_dis-dist_20230324060000_v3.4.0.cdf
# 18-Dec-25 14:36:15: The name mms1_dis_pitchangdist_lowen_fast is currently not in pyspedas
# 18-Dec-25 14:36:15: The name mms1_dis_pitchangdist_miden_fast is currently not in pyspedas
# 18-Dec-25 14:36:15: The name mms1_dis_pitchangdist_highen_fast is currently not in pyspedas
# 18-Dec-25 14:36:15: Loading files for group: probe: 1, drate: srvy, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:15: pydata/mms1/fgm/srvy/l2/2023/03/mms1_fgm_srvy_l2_20230324_v5.393.0.cdf
# 18-Dec-25 14:36:19: Downloading mms1_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf to pydata/mms1/fpi/fast/l2/dis-moms/2023/03
# 18-Dec-25 14:36:20: Loading files for group: probe: 1, drate: fast, level: l2, datatype: dis-moms, after sorting and filtering:
# 18-Dec-25 14:36:20: pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf
# 18-Dec-25 14:36:20: The name mms1_dis_pitchangdist_lowen_fast is currently not in pyspedas
# 18-Dec-25 14:36:20: The name mms1_dis_pitchangdist_miden_fast is currently not in pyspedas
# 18-Dec-25 14:36:20: The name mms1_dis_pitchangdist_highen_fast is currently not in pyspedas
# 18-Dec-25 14:36:20: Averaging mms1_fgm_b_gse_srvy_l2_bvec
# 18-Dec-25 14:36:20: Averaging mms1_dis_bulkv_gse_fast
# 18-Dec-25 14:36:20: Aligning slice plane to: bv
# 18-Dec-25 14:36:26: Finished slice at 2023-03-24 07:07:29.408840

# %% [markdown]
# The slice is stored as a dictionary:

# %%
the_slice.keys()
# Out:
# dict_keys(['project_name', 'spacecraft', 'data_name', 'units_name', 'species', 'xyunits', 'rotation', 'energy', 'trange', 'zrange', 'rrange', 'rlog', 'interpolation', 'n_samples', 'data', 'xgrid', 'ygrid'])

# %% [markdown]
# You can also create 1D cuts through the 2D slice:

# %%
from pyspedas.particles.spd_slice2d.slice1d_plot import plot

plot(the_slice, 'x', [-100, 100])  # summed from Vv=[-100, 100]

# %% [markdown]
# ## FPI ions with 2D interpolation
#
# The data are rotated such that the x axis is parallel to B field and the bulk velocity defines the x-y plane, and plotted using 2D interpolation (data points within the specified theta or z-axis range are projected onto the slice plane and linearly interpolated onto a regular 2D grid). The default theta range is [-20, +20]

# %%
mms_part_slice2d(interpolation='2d', time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])
# Out:
# 18-Dec-25 14:36:27: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-dist, after sorting and filtering:
# 18-Dec-25 14:36:27: pydata/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:36:28: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:36:28: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:36:28: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:36:28: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:28: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:28: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:36:28: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:28: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:28: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:36:28: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:28: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:36:29: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-moms, after sorting and filtering:
# 18-Dec-25 14:36:29: pydata/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:36:29: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:36:29: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:36:29: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:36:29: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:29: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:29: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:36:29: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:29: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:29: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:36:29: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:36:29: Averaging mms1_dis_bulkv_gse_brst
# 18-Dec-25 14:36:29: Aligning slice plane to: bv
# 18-Dec-25 14:36:29: Finished slice at 2023-03-24 07:07:32.858868

# %% [markdown]
# ## HPCA H+ with geometric interpolation
#
# Same as above, but with HPCA H+ data

# %%
mms_part_slice2d(time=time, instrument='hpca', species='hplus', data_rate='brst', rotation='bv', erange=[0, 20000])
# Out:
# 18-Dec-25 14:36:30: Downloading mms1_hpca_brst_l2_ion_20230324070453_v4.3.1.cdf to pydata/mms1/hpca/brst/l2/ion/2023/03/24
# 18-Dec-25 14:36:31: Loading files for group: probe: 1, drate: brst, level: l2, datatype: ion, after sorting and filtering:
# 18-Dec-25 14:36:31: pydata/mms1/hpca/brst/l2/ion/2023/03/24/mms1_hpca_brst_l2_ion_20230324070453_v4.3.1.cdf
# 18-Dec-25 14:36:31: Variable mms1_hpca_hplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:31: Variable mms1_hpca_heplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:31: Variable mms1_hpca_heplusplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:31: Variable mms1_hpca_oplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:31: wildcard_expand: No match found for mms1*_number_density
# 18-Dec-25 14:36:31: wildcard_expand: No match found for mms1*_ion_bulk_velocity*
# 18-Dec-25 14:36:31: wildcard_expand: No match found for mms1*_scalar_temperature
# 18-Dec-25 14:36:31: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:31: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:36:31: Downloading mms1_hpca_brst_l2_moments_20230324070453_v4.3.1.cdf to pydata/mms1/hpca/brst/l2/moments/2023/03/24
# 18-Dec-25 14:36:32: Loading files for group: probe: 1, drate: brst, level: l2, datatype: moments, after sorting and filtering:
# 18-Dec-25 14:36:32: pydata/mms1/hpca/brst/l2/moments/2023/03/24/mms1_hpca_brst_l2_moments_20230324070453_v4.3.1.cdf
# 18-Dec-25 14:36:32: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:36:32: Averaging mms1_hpca_hplus_ion_bulk_velocity
# 18-Dec-25 14:36:32: Aligning slice plane to: bv
# 18-Dec-25 14:36:34: Finished slice at 2023-03-24 07:07:28.880060

# %% [markdown]
# ## HPCA H+ with 2d interpolation
#
# and with 2D interpolation. Note that with 2D interpolation, smoothing is enabled by default and set to 7 points; you can override this with the smooth keyword

# %%
mms_part_slice2d(interpolation='2d', time=time, instrument='hpca', data_rate='brst', species='hplus', rotation='bv', erange=[0, 20000])
# Out:
# 18-Dec-25 14:36:35: Loading files for group: probe: 1, drate: brst, level: l2, datatype: ion, after sorting and filtering:
# 18-Dec-25 14:36:35: pydata/mms1/hpca/brst/l2/ion/2023/03/24/mms1_hpca_brst_l2_ion_20230324070453_v4.3.1.cdf
# 18-Dec-25 14:36:35: Variable mms1_hpca_hplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:35: Variable mms1_hpca_heplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:35: Variable mms1_hpca_heplusplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:35: Variable mms1_hpca_oplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:35: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:35: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:36:35: Loading files for group: probe: 1, drate: brst, level: l2, datatype: moments, after sorting and filtering:
# 18-Dec-25 14:36:35: pydata/mms1/hpca/brst/l2/moments/2023/03/24/mms1_hpca_brst_l2_moments_20230324070453_v4.3.1.cdf
# 18-Dec-25 14:36:36: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:36:36: Averaging mms1_hpca_hplus_ion_bulk_velocity
# 18-Dec-25 14:36:36: Aligning slice plane to: bv
# 18-Dec-25 14:36:36: Finished slice at 2023-03-24 07:07:28.880060

# %% [markdown]
# Change the rotation such that the x axis is parallel to B field; the B x V(bulk) vector defines the x-y plane:

# %%
mms_part_slice2d(interpolation='2d', time=time, instrument='hpca', data_rate='brst', species='hplus', rotation='be', erange=[0, 20000])
# Out:
# 18-Dec-25 14:36:36: Loading files for group: probe: 1, drate: brst, level: l2, datatype: ion, after sorting and filtering:
# 18-Dec-25 14:36:36: pydata/mms1/hpca/brst/l2/ion/2023/03/24/mms1_hpca_brst_l2_ion_20230324070453_v4.3.1.cdf
# 18-Dec-25 14:36:36: Variable mms1_hpca_hplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:36: Variable mms1_hpca_heplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:36: Variable mms1_hpca_heplusplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:36: Variable mms1_hpca_oplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:36:37: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:37: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:36:37: Loading files for group: probe: 1, drate: brst, level: l2, datatype: moments, after sorting and filtering:
# 18-Dec-25 14:36:37: pydata/mms1/hpca/brst/l2/moments/2023/03/24/mms1_hpca_brst_l2_moments_20230324070453_v4.3.1.cdf
# 18-Dec-25 14:36:37: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:36:37: Averaging mms1_hpca_hplus_ion_bulk_velocity
# 18-Dec-25 14:36:37: Aligning slice plane to: be
# 18-Dec-25 14:36:38: Finished slice at 2023-03-24 07:07:28.880060

# %% [markdown]
# To see the other options, run help() on mms_part_slice2d:

# %%
help(mms_part_slice2d)
# Out:
# Help on function mms_part_slice2d in module pyspedas.projects.mms.particles.mms_part_slice2d:
#
# mms_part_slice2d(trange=None, time=None, samples=None, window=None, center_time=False, erange=None, thetarange=None, zdirrange=None, average_angle=None, sum_angle=None, energy=False, log=False, probe='1', instrument='fpi', data_rate=None, level='l2', spdf=False, mag_data_rate=None, species=None, rotation='xy', custom_rotation=None, slice_x=None, slice_norm=None, subtract_bulk=False, xrange=None, yrange=None, zrange=None, resolution=None, interpolation='geometric', contours=False, title=None, smooth=None, save_jpeg=None, save_png=None, save_svg=None, save_pdf=None, save_eps=None, plotsize=10, dpi=None, return_slice=False, cmap=None, display=True)
#     This routine creates 2D slices of 3D distribution function data from the FPI and HPCA instruments.
#     This is essentially a wrapper around slice2d and slice2d_plot, that loads the data,
#     any required support data, calculates the slice with slice2d and plots it with slice2d_plot.
#
#     Parameters
#     -----------
#         probe: int or str
#             MMS spacecraft probe # (1, 2, 3 or 4)
#
#         instrument: str
#             MMS plasma instrument (fpi or hpca)
#
#         species: str
#             Particle species; depends on the instrument::
#
#                 FPI: 'e' for electrons, 'i' for ions
#                 HPCA: 'hplus' for H+, 'oplus' for O+, 'heplus' for He+, 'heplusplus', for He++
#
#         data_rate: str
#             FPI/HPCA data rate [fast (fpi), srvy (hpca), or brst (both fpi and hpca)]
#
#         mag_data_rate: str
#             FGM data rate for transformations
#
#         level: str
#             Data level (default: l2); lower levels require an SDC username and password
#
#         spdf: bool
#             Flag to download the data from SPDF instead of the MMS SDC
#
#         trange: list of str or list of float
#             Two-element time range over which data will be averaged (optional; can also use the 'time' keyword)
#
#         time: str or float
#             Time at which the slice will be computed (optional; can also use 'trange' above)
#
#         samples: int
#             Number of nearest samples to TIME to average.
#
#         window: float
#             Length in seconds from TIME over which data will be averaged
#
#         center_time: bool
#             Flag denoting that TIME should be midpoint for window instead of beginning
#
#         interpolation: str
#             Interpolation method; valid options::
#
#                 'geometric': Each point on the plot is given the value of the bin it intersects.
#                             This allows bin boundaries to be drawn at high resolutions.
#                 '2d': Data points within the specified theta or z-axis range are projected onto
#                             the slice plane and linearly interpolated onto a regular 2D grid.
#
#         rotation: str
#             Aligns the data relative to the magnetic field and/or bulk velocity.
#             This is applied after the CUSTOM_ROTATION. (BV and BE are invariant
#             between coordinate systems); valid options::
#
#                 'BV':  The x axis is parallel to B field; the bulk velocity defines the x-y plane
#                 'BE':  The x axis is parallel to B field; the B x V(bulk) vector defines the x-y plane
#                 'xy':  (default) The x axis is along the data's x axis and y is along the data's y axis
#                 'xz':  The x axis is along the data's x axis and y is along the data's z axis
#                 'yz':  The x axis is along the data's y axis and y is along the data's z axis
#                 'xvel':  The x axis is along the data's x axis; the x-y plane is defined by the bulk velocity
#                 'perp':  The x axis is the bulk velocity projected onto the plane normal to the B field; y is B x V(bulk)
#                 'perp_xy':  The data's x & y axes are projected onto the plane normal to the B field
#                 'perp_xz':  The data's x & z axes are projected onto the plane normal to the B field
#                 'perp_yz':  The data's y & z axes are projected onto the plane normal to the B field
#
#         custom_rotation: str or np.ndarray
#             Applies a custom rotation matrix to the data.  Input may be a
#             3x3 rotation matrix or a tplot variable containing matrices.
#             If the time window covers multiple matrices they will be averaged.
#             This is applied before other transformations
#
#         slice_x: str or np.ndarray
#             Specifies the slice plane's x-axis within the coordinates
#             specified by custom_rotation and rotation. If not specified, the given
#             coordinate's x-axis will be used. If slice_x is not perpendicular to the
#             normal, its projection onto the slice plane will be used.
#
#         slice_norm: str or np.ndarray
#             Specifies the slice plane's normal within the coordinates
#             specified by custom_rotation and rotation; if not specified, the given
#             coordinate's z-axis will be used (slice along by x-y plane in those coordinates).
#
#         energy: bool
#             Flag to plot data against energy (in eV) instead of velocity.
#
#         log: bool
#             Flag to apply logarithmic scaling to the radial measure (i.e. energy/velocity).
#             (on by default if ENERGY is True)
#
#         erange: list of float
#             Two element array specifying the energy range to be used in eV
#
#         thetarange: list of float
#             (2D interpolation only) Angle range, in degrees [-90,90], used to calculate slice.
#             Default = [-20,20]; will override ZDIRRANGE.
#
#         zdirrange: list of float
#             (2D interpolation only) Z-Axis range, in km/s, used to calculate slice.
#             Ignored if called with THETARANGE.
#
#         subtract_bulk: bool
#             Subtract the bulk velocity vector
#
#         resolution: int
#             Integer specifying the resolution along each dimension of the
#             slice (defaults:  2D interpolation: 150, geometric: 500)
#
#         smooth: int
#             An odd integer >=3 specifying the width of a smoothing window in #
#             of points.  Smoothing is applied to the final plot using a gaussian
#             convolution. Even entries will be incremented, 0 and 1 are ignored.
#
#         xrange: list of float
#             Keyword to limit the range of the slice's x-axis in the plot
#
#         yrange: list of float
#             Keyword to limit the range of the slice's y-axis in the plot
#
#         zrange: list of float
#             Keyword to limit the range of the slice's color bar
#
#         save_png: str
#             Save the plot as a PNG file
#
#         save_eps: str
#             Save the plot as an EPS file
#
#         save_pdf: str
#             Save the plot as a PDF file
#
#         save_svg: str
#             Save the plot as an SVG file
#
#         display: bool
#             Flag to allow disabling displaying of the figure
#
#         return_slice: bool
#             Flag to return the slice instead of displaying it
#
#     Returns
#     --------
#     None or dict
#         By default, no return value (but creates a figure). If return_slice=True, returns the slice data structure.
#
#     Examples
#     --------
#
#     >>> from pyspedas.projects.mms import mms_part_slice2d
#     >>> time = '2023-03-24/07:07:33'
#     >>> # FPI ions with geometric interpolation
#     >>> mms_part_slice2d(time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])
#     >>> # Same as above, but return the slice data structure
#     >>> the_slice = mms_part_slice2d(return_slice=True, time=time, instrument='fpi', species='i', rotation='bv', erange=[0, 20000])
#     >>> # FPI ions with 2D interpolation
#     >>> mms_part_slice2d(interpolation='2d', time=time, instrument='fpi', data_rate='brst', species='i', rotation='bv', erange=[0, 20000])

# %%
import pyspedas
pyspedas.tplot_names()
# Out:
# 0 : Epoch
# 1 : Epoch_plus_var
# 2 : Epoch_minus_var
# 3 : mms1_dis_errorflags_brst_dist
# 4 : mms1_dis_compressionloss_brst_dist
# 5 : mms1_dis_steptable_parity_brst
# 6 : mms1_dis_startdelphi_count_brst
# 7 : mms1_dis_startdelphi_angle_brst
# 8 : mms1_dis_phi_brst
# 9 : mms1_dis_phi_delta_brst
# 10 : mms1_dis_dist_brst
# 11 : mms1_dis_disterr_brst
# 12 : mms1_dis_avgf1counts_brst
# 13 : mms1_dis_steptimeoffsets_brst
# 14 : mms1_dis_sector_despinp_brst
# 15 : mms1_dis_theta_brst
# 16 : mms1_dis_theta_delta_brst
# 17 : mms1_dis_energy_brst
# 18 : mms1_dis_energy_delta_brst
# 19 : mms1_dis_errorflags_brst_dist_flagbars_dist
# 20 : mms1_dis_compressionloss_brst_dist_flagbars
# 21 : mms1_fgm_b_gse_brst_l2
# 22 : mms1_fgm_b_gsm_brst_l2
# 23 : mms1_fgm_b_dmpa_brst_l2
# 24 : mms1_fgm_b_bcs_brst_l2
# 25 : mms1_fgm_flag_brst_l2
# 26 : Epoch_state
# 27 : mms1_fgm_hirange_brst_l2
# 28 : mms1_fgm_bdeltahalf_brst_l2
# 29 : mms1_fgm_stemp_brst_l2
# 30 : mms1_fgm_etemp_brst_l2
# 31 : mms1_fgm_mode_brst_l2
# 32 : mms1_fgm_b_dmpa_brst_l2_bvec
# 33 : mms1_fgm_b_dmpa_brst_l2_btot
# 34 : mms1_fgm_b_gse_brst_l2_bvec
# 35 : mms1_fgm_b_gse_brst_l2_btot
# 36 : mms1_fgm_b_gsm_brst_l2_bvec
# 37 : mms1_fgm_b_gsm_brst_l2_btot
# 38 : mms1_fgm_b_bcs_brst_l2_bvec
# 39 : mms1_fgm_b_bcs_brst_l2_btot
# 40 : mms1_dis_errorflags_brst_moms
# 41 : mms1_dis_compressionloss_brst_moms
# 42 : mms1_dis_energyspectr_px_brst
# 43 : mms1_dis_energyspectr_mx_brst
# 44 : mms1_dis_energyspectr_py_brst
# 45 : mms1_dis_energyspectr_my_brst
# 46 : mms1_dis_energyspectr_pz_brst
# 47 : mms1_dis_energyspectr_mz_brst
# 48 : mms1_dis_energyspectr_omni_brst
# 49 : mms1_dis_spectr_bg_brst
# 50 : mms1_dis_numberdensity_bg_brst
# 51 : mms1_dis_numberdensity_brst
# 52 : mms1_dis_numberdensity_err_brst
# 53 : mms1_dis_densityextrapolation_low_brst
# 54 : mms1_dis_densityextrapolation_high_brst
# 55 : mms1_dis_bulkv_dbcs_brst
# 56 : mms1_dis_bulkv_spintone_dbcs_brst
# 57 : mms1_dis_bulkv_gse_brst
# 58 : mms1_dis_bulkv_spintone_gse_brst
# 59 : mms1_dis_bulkv_err_brst
# 60 : mms1_dis_prestensor_dbcs_brst
# 61 : mms1_dis_prestensor_gse_brst
# 62 : mms1_dis_prestensor_err_brst
# 63 : mms1_dis_pres_bg_brst
# 64 : mms1_dis_temptensor_dbcs_brst
# 65 : mms1_dis_temptensor_gse_brst
# 66 : mms1_dis_temptensor_err_brst
# 67 : mms1_dis_heatq_dbcs_brst
# 68 : mms1_dis_heatq_gse_brst
# 69 : mms1_dis_heatq_err_brst
# 70 : mms1_dis_temppara_brst
# 71 : mms1_dis_tempperp_brst
# 72 : mms1_dis_errorflags_brst_moms_flagbars_full
# 73 : mms1_dis_errorflags_brst_moms_flagbars_main
# 74 : mms1_dis_errorflags_brst_moms_flagbars_others
# 75 : mms1_dis_errorflags_brst_moms_flagbars_mini
# 76 : mms1_dis_compressionloss_brst_moms_flagbars
# 77 : mms1_dis_errorflags_fast_dist
# 78 : mms1_dis_compressionloss_fast_dist
# 79 : mms1_dis_startdelphi_count_fast
# 80 : mms1_dis_startdelphi_angle_fast
# 81 : mms1_dis_dist_fast
# 82 : mms1_dis_disterr_fast
# 83 : mms1_dis_avgf1counts_fast
# 84 : mms1_dis_theta_fast
# 85 : mms1_dis_theta_delta_fast
# 86 : mms1_dis_energy_fast
# 87 : mms1_dis_energy_delta_fast
# 88 : mms1_dis_phi_fast
# 89 : mms1_dis_phi_delta_fast
# 90 : mms1_dis_errorflags_fast_dist_flagbars_dist
# 91 : mms1_fgm_b_gse_srvy_l2
# 92 : mms1_fgm_b_gsm_srvy_l2
# 93 : mms1_fgm_b_dmpa_srvy_l2
# 94 : mms1_fgm_b_bcs_srvy_l2
# 95 : mms1_fgm_flag_srvy_l2
# 96 : mms1_fgm_hirange_srvy_l2
# 97 : mms1_fgm_bdeltahalf_srvy_l2
# 98 : mms1_fgm_stemp_srvy_l2
# 99 : mms1_fgm_etemp_srvy_l2
# 100 : mms1_fgm_mode_srvy_l2
# 101 : mms1_fgm_b_dmpa_srvy_l2_bvec
# 102 : mms1_fgm_b_dmpa_srvy_l2_btot
# 103 : mms1_fgm_b_gse_srvy_l2_bvec
# 104 : mms1_fgm_b_gse_srvy_l2_btot
# 105 : mms1_fgm_b_gsm_srvy_l2_bvec
# 106 : mms1_fgm_b_gsm_srvy_l2_btot
# 107 : mms1_fgm_b_bcs_srvy_l2_bvec
# 108 : mms1_fgm_b_bcs_srvy_l2_btot
# 109 : mms1_dis_errorflags_fast_moms
# 110 : mms1_dis_compressionloss_fast_moms
# 111 : mms1_dis_energyspectr_px_fast
# 112 : mms1_dis_energyspectr_mx_fast
# 113 : mms1_dis_energyspectr_py_fast
# 114 : mms1_dis_energyspectr_my_fast
# 115 : mms1_dis_energyspectr_pz_fast
# 116 : mms1_dis_energyspectr_mz_fast
# 117 : mms1_dis_energyspectr_omni_fast
# 118 : mms1_dis_spectr_bg_fast
# 119 : mms1_dis_numberdensity_bg_fast
# 120 : mms1_dis_numberdensity_fast
# 121 : mms1_dis_numberdensity_err_fast
# 122 : mms1_dis_densityextrapolation_low_fast
# 123 : mms1_dis_densityextrapolation_high_fast
# 124 : mms1_dis_bulkv_dbcs_fast
# 125 : mms1_dis_bulkv_spintone_dbcs_fast
# 126 : mms1_dis_bulkv_gse_fast
# 127 : mms1_dis_bulkv_spintone_gse_fast
# 128 : mms1_dis_bulkv_err_fast
# 129 : mms1_dis_prestensor_dbcs_fast
# 130 : mms1_dis_prestensor_gse_fast
# 131 : mms1_dis_prestensor_err_fast
# 132 : mms1_dis_pres_bg_fast
# 133 : mms1_dis_temptensor_dbcs_fast
# 134 : mms1_dis_temptensor_gse_fast
# 135 : mms1_dis_temptensor_err_fast
# 136 : mms1_dis_heatq_dbcs_fast
# 137 : mms1_dis_heatq_gse_fast
# 138 : mms1_dis_heatq_err_fast
# 139 : mms1_dis_temppara_fast
# 140 : mms1_dis_tempperp_fast
# 141 : mms1_dis_errorflags_fast_moms_flagbars_full
# 142 : mms1_dis_errorflags_fast_moms_flagbars_main
# 143 : mms1_dis_errorflags_fast_moms_flagbars_others
# 144 : mms1_dis_errorflags_fast_moms_flagbars_mini
# 145 : Epoch_MINUS
# 146 : Epoch_PLUS
# 147 : mms1_hpca_polar_anode_number
# 148 : mms1_hpca_azimuth_decimation_factor
# 149 : mms1_hpca_polar_decimation_factor
# 150 : mms1_hpca_energy_decimation_factor
# 151 : mms1_hpca_sweep_table_number
# 152 : mms1_hpca_start_azimuth
# 153 : mms1_hpca_science_mode
# 154 : mms1_hpca_ion_energy
# 155 : mms1_hpca_hplus_flux
# 156 : mms1_hpca_hplus_phase_space_density
# 157 : mms1_hpca_hplus_data_quality
# 158 : mms1_hpca_heplus_flux
# 159 : mms1_hpca_heplus_phase_space_density
# 160 : mms1_hpca_heplus_data_quality
# 161 : mms1_hpca_heplusplus_flux
# 162 : mms1_hpca_heplusplus_phase_space_density
# 163 : mms1_hpca_heplusplus_data_quality
# 164 : mms1_hpca_oplus_flux
# 165 : mms1_hpca_oplus_phase_space_density
# 166 : mms1_hpca_oplus_data_quality
# 167 : mms1_hpca_B_GSE_sweep_avg
# 168 : mms1_hpca_B_GSM_sweep_avg
# 169 : Epoch_Angles
# 170 : Epoch_MINUS_Angles
# 171 : Epoch_PLUS_Angles
# 172 : mms1_hpca_azimuth_angles_degrees
# 173 : mms1_hpca_azimuth_angles_per_ev_degrees
# 174 : mms1_hpca_centroid_elevation_angle
# 175 : mms1_hpca_azimuth_index
# 176 : mms1_hpca_energy_step_number
# 177 : mms1_hpca_MCP_VMON_MIN_converted
# 178 : mms1_hpca_TOF_VMON_MIN_converted
# 179 : mms1_hpca_decimation_factor_index
# 180 : mms1_hpca_acquisition_time
# 181 : mms1_hpca_spin_number
# 182 : mms1_hpca_hplus_number_density
# 183 : mms1_hpca_hplus_ion_bulk_velocity
# 184 : mms1_hpca_hplus_scalar_temperature
# 185 : mms1_hpca_hplus_ion_pressure
# 186 : mms1_hpca_hplus_temperature_tensor
# 187 : mms1_hpca_heplus_number_density
# 188 : mms1_hpca_heplus_ion_bulk_velocity
# 189 : mms1_hpca_heplus_scalar_temperature
# 190 : mms1_hpca_heplus_ion_pressure
# 191 : mms1_hpca_heplus_temperature_tensor
# 192 : mms1_hpca_heplusplus_number_density
# 193 : mms1_hpca_heplusplus_ion_bulk_velocity
# 194 : mms1_hpca_heplusplus_scalar_temperature
# 195 : mms1_hpca_heplusplus_ion_pressure
# 196 : mms1_hpca_heplusplus_temperature_tensor
# 197 : mms1_hpca_oplus_number_density
# 198 : mms1_hpca_oplus_ion_bulk_velocity
# 199 : mms1_hpca_oplus_scalar_temperature
# 200 : mms1_hpca_oplus_ion_pressure
# 201 : mms1_hpca_oplus_temperature_tensor
# 202 : mms1_hpca_B_GSE_spin_avg
# 203 : mms1_hpca_B_GSM_spin_avg
# 204 : mms1_hpca_hplus_ion_bulk_velocity_GSM
# 205 : mms1_hpca_hplus_tperp
# 206 : mms1_hpca_hplus_tparallel
# 207 : mms1_hpca_hplus_vperp
# 208 : mms1_hpca_hplus_vparallel
# 209 : mms1_hpca_hplus_vperp_GSM
# 210 : mms1_hpca_hplus_vparallel_GSM
# 211 : mms1_hpca_heplus_ion_bulk_velocity_GSM
# 212 : mms1_hpca_heplus_tperp
# 213 : mms1_hpca_heplus_tparallel
# 214 : mms1_hpca_heplus_vperp
# 215 : mms1_hpca_heplus_vparallel
# 216 : mms1_hpca_heplus_vperp_GSM
# 217 : mms1_hpca_heplus_vparallel_GSM
# 218 : mms1_hpca_heplusplus_ion_bulk_velocity_GSM
# 219 : mms1_hpca_heplusplus_tperp
# 220 : mms1_hpca_heplusplus_tparallel
# 221 : mms1_hpca_heplusplus_vperp
# 222 : mms1_hpca_heplusplus_vparallel
# 223 : mms1_hpca_heplusplus_vperp_GSM
# 224 : mms1_hpca_heplusplus_vparallel_GSM
# 225 : mms1_hpca_oplus_ion_bulk_velocity_GSM
# 226 : mms1_hpca_oplus_tperp
# 227 : mms1_hpca_oplus_tparallel
# 228 : mms1_hpca_oplus_vperp
# 229 : mms1_hpca_oplus_vparallel
# 230 : mms1_hpca_oplus_vperp_GSM
# 231 : mms1_hpca_oplus_vparallel_GSM
# ['Epoch',
#  'Epoch_plus_var',
#  'Epoch_minus_var',
#  'mms1_dis_errorflags_brst_dist',
#  'mms1_dis_compressionloss_brst_dist',
#  'mms1_dis_steptable_parity_brst',
#  'mms1_dis_startdelphi_count_brst',
#  'mms1_dis_startdelphi_angle_brst',
#  'mms1_dis_phi_brst',
#  'mms1_dis_phi_delta_brst',
#  'mms1_dis_dist_brst',
#  'mms1_dis_disterr_brst',
#  'mms1_dis_avgf1counts_brst',
#  'mms1_dis_steptimeoffsets_brst',
#  'mms1_dis_sector_despinp_brst',
#  'mms1_dis_theta_brst',
#  'mms1_dis_theta_delta_brst',
#  'mms1_dis_energy_brst',
#  'mms1_dis_energy_delta_brst',
#  'mms1_dis_errorflags_brst_dist_flagbars_dist',
#  'mms1_dis_compressionloss_brst_dist_flagbars',
#  'mms1_fgm_b_gse_brst_l2',
#  'mms1_fgm_b_gsm_brst_l2',
#  'mms1_fgm_b_dmpa_brst_l2',
#  'mms1_fgm_b_bcs_brst_l2',
#  'mms1_fgm_flag_brst_l2',
#  'Epoch_state',
#  'mms1_fgm_hirange_brst_l2',
#  'mms1_fgm_bdeltahalf_brst_l2',
#  'mms1_fgm_stemp_brst_l2',
#  'mms1_fgm_etemp_brst_l2',
#  'mms1_fgm_mode_brst_l2',
#  'mms1_fgm_b_dmpa_brst_l2_bvec',
#  'mms1_fgm_b_dmpa_brst_l2_btot',
#  'mms1_fgm_b_gse_brst_l2_bvec',
#  'mms1_fgm_b_gse_brst_l2_btot',
#  'mms1_fgm_b_gsm_brst_l2_bvec',
#  'mms1_fgm_b_gsm_brst_l2_btot',
#  'mms1_fgm_b_bcs_brst_l2_bvec',
#  'mms1_fgm_b_bcs_brst_l2_btot',
#  'mms1_dis_errorflags_brst_moms',
#  'mms1_dis_compressionloss_brst_moms',
#  'mms1_dis_energyspectr_px_brst',
#  'mms1_dis_energyspectr_mx_brst',
#  'mms1_dis_energyspectr_py_brst',
#  'mms1_dis_energyspectr_my_brst',
#  'mms1_dis_energyspectr_pz_brst',
#  'mms1_dis_energyspectr_mz_brst',
#  'mms1_dis_energyspectr_omni_brst',
#  'mms1_dis_spectr_bg_brst',
#  'mms1_dis_numberdensity_bg_brst',
#  'mms1_dis_numberdensity_brst',
#  'mms1_dis_numberdensity_err_brst',
#  'mms1_dis_densityextrapolation_low_brst',
#  'mms1_dis_densityextrapolation_high_brst',
#  'mms1_dis_bulkv_dbcs_brst',
#  'mms1_dis_bulkv_spintone_dbcs_brst',
#  'mms1_dis_bulkv_gse_brst',
#  'mms1_dis_bulkv_spintone_gse_brst',
#  'mms1_dis_bulkv_err_brst',
#  'mms1_dis_prestensor_dbcs_brst',
#  'mms1_dis_prestensor_gse_brst',
#  'mms1_dis_prestensor_err_brst',
#  'mms1_dis_pres_bg_brst',
#  'mms1_dis_temptensor_dbcs_brst',
#  'mms1_dis_temptensor_gse_brst',
#  'mms1_dis_temptensor_err_brst',
#  'mms1_dis_heatq_dbcs_brst',
#  'mms1_dis_heatq_gse_brst',
#  'mms1_dis_heatq_err_brst',
#  'mms1_dis_temppara_brst',
#  'mms1_dis_tempperp_brst',
#  'mms1_dis_errorflags_brst_moms_flagbars_full',
#  'mms1_dis_errorflags_brst_moms_flagbars_main',
#  'mms1_dis_errorflags_brst_moms_flagbars_others',
#  'mms1_dis_errorflags_brst_moms_flagbars_mini',
#  'mms1_dis_compressionloss_brst_moms_flagbars',
#  'mms1_dis_errorflags_fast_dist',
#  'mms1_dis_compressionloss_fast_dist',
#  'mms1_dis_startdelphi_count_fast',
#  'mms1_dis_startdelphi_angle_fast',
#  'mms1_dis_dist_fast',
#  'mms1_dis_disterr_fast',
#  'mms1_dis_avgf1counts_fast',
#  'mms1_dis_theta_fast',
#  'mms1_dis_theta_delta_fast',
#  'mms1_dis_energy_fast',
#  'mms1_dis_energy_delta_fast',
#  'mms1_dis_phi_fast',
#  'mms1_dis_phi_delta_fast',
#  'mms1_dis_errorflags_fast_dist_flagbars_dist',
#  'mms1_fgm_b_gse_srvy_l2',
#  'mms1_fgm_b_gsm_srvy_l2',
#  'mms1_fgm_b_dmpa_srvy_l2',
#  'mms1_fgm_b_bcs_srvy_l2',
#  'mms1_fgm_flag_srvy_l2',
#  'mms1_fgm_hirange_srvy_l2',
#  'mms1_fgm_bdeltahalf_srvy_l2',
#  'mms1_fgm_stemp_srvy_l2',
#  'mms1_fgm_etemp_srvy_l2',
#  'mms1_fgm_mode_srvy_l2',
#  'mms1_fgm_b_dmpa_srvy_l2_bvec',
#  'mms1_fgm_b_dmpa_srvy_l2_btot',
#  'mms1_fgm_b_gse_srvy_l2_bvec',
#  'mms1_fgm_b_gse_srvy_l2_btot',
#  'mms1_fgm_b_gsm_srvy_l2_bvec',
#  'mms1_fgm_b_gsm_srvy_l2_btot',
#  'mms1_fgm_b_bcs_srvy_l2_bvec',
#  'mms1_fgm_b_bcs_srvy_l2_btot',
#  'mms1_dis_errorflags_fast_moms',
#  'mms1_dis_compressionloss_fast_moms',
#  'mms1_dis_energyspectr_px_fast',
#  'mms1_dis_energyspectr_mx_fast',
#  'mms1_dis_energyspectr_py_fast',
#  'mms1_dis_energyspectr_my_fast',
#  'mms1_dis_energyspectr_pz_fast',
#  'mms1_dis_energyspectr_mz_fast',
#  'mms1_dis_energyspectr_omni_fast',
#  'mms1_dis_spectr_bg_fast',
#  'mms1_dis_numberdensity_bg_fast',
#  'mms1_dis_numberdensity_fast',
#  'mms1_dis_numberdensity_err_fast',
#  'mms1_dis_densityextrapolation_low_fast',
#  'mms1_dis_densityextrapolation_high_fast',
#  'mms1_dis_bulkv_dbcs_fast',
#  'mms1_dis_bulkv_spintone_dbcs_fast',
#  'mms1_dis_bulkv_gse_fast',
#  'mms1_dis_bulkv_spintone_gse_fast',
#  'mms1_dis_bulkv_err_fast',
#  'mms1_dis_prestensor_dbcs_fast',
#  'mms1_dis_prestensor_gse_fast',
#  'mms1_dis_prestensor_err_fast',
#  'mms1_dis_pres_bg_fast',
#  'mms1_dis_temptensor_dbcs_fast',
#  'mms1_dis_temptensor_gse_fast',
#  'mms1_dis_temptensor_err_fast',
#  'mms1_dis_heatq_dbcs_fast',
#  'mms1_dis_heatq_gse_fast',
#  'mms1_dis_heatq_err_fast',
#  'mms1_dis_temppara_fast',
#  'mms1_dis_tempperp_fast',
#  'mms1_dis_errorflags_fast_moms_flagbars_full',
#  'mms1_dis_errorflags_fast_moms_flagbars_main',
#  'mms1_dis_errorflags_fast_moms_flagbars_others',
#  'mms1_dis_errorflags_fast_moms_flagbars_mini',
#  'Epoch_MINUS',
#  'Epoch_PLUS',
#  'mms1_hpca_polar_anode_number',
#  'mms1_hpca_azimuth_decimation_factor',
#  'mms1_hpca_polar_decimation_factor',
#  'mms1_hpca_energy_decimation_factor',
#  'mms1_hpca_sweep_table_number',
#  'mms1_hpca_start_azimuth',
#  'mms1_hpca_science_mode',
#  'mms1_hpca_ion_energy',
#  'mms1_hpca_hplus_flux',
#  'mms1_hpca_hplus_phase_space_density',
#  'mms1_hpca_hplus_data_quality',
#  'mms1_hpca_heplus_flux',
#  'mms1_hpca_heplus_phase_space_density',
#  'mms1_hpca_heplus_data_quality',
#  'mms1_hpca_heplusplus_flux',
#  'mms1_hpca_heplusplus_phase_space_density',
#  'mms1_hpca_heplusplus_data_quality',
#  'mms1_hpca_oplus_flux',
#  'mms1_hpca_oplus_phase_space_density',
#  'mms1_hpca_oplus_data_quality',
#  'mms1_hpca_B_GSE_sweep_avg',
#  'mms1_hpca_B_GSM_sweep_avg',
#  'Epoch_Angles',
#  'Epoch_MINUS_Angles',
#  'Epoch_PLUS_Angles',
#  'mms1_hpca_azimuth_angles_degrees',
#  'mms1_hpca_azimuth_angles_per_ev_degrees',
#  'mms1_hpca_centroid_elevation_angle',
#  'mms1_hpca_azimuth_index',
#  'mms1_hpca_energy_step_number',
#  'mms1_hpca_MCP_VMON_MIN_converted',
#  'mms1_hpca_TOF_VMON_MIN_converted',
#  'mms1_hpca_decimation_factor_index',
#  'mms1_hpca_acquisition_time',
#  'mms1_hpca_spin_number',
#  'mms1_hpca_hplus_number_density',
#  'mms1_hpca_hplus_ion_bulk_velocity',
#  'mms1_hpca_hplus_scalar_temperature',
#  'mms1_hpca_hplus_ion_pressure',
#  'mms1_hpca_hplus_temperature_tensor',
#  'mms1_hpca_heplus_number_density',
#  'mms1_hpca_heplus_ion_bulk_velocity',
#  'mms1_hpca_heplus_scalar_temperature',
#  'mms1_hpca_heplus_ion_pressure',
#  'mms1_hpca_heplus_temperature_tensor',
#  'mms1_hpca_heplusplus_number_density',
#  'mms1_hpca_heplusplus_ion_bulk_velocity',
#  'mms1_hpca_heplusplus_scalar_temperature',
#  'mms1_hpca_heplusplus_ion_pressure',
#  'mms1_hpca_heplusplus_temperature_tensor',
#  'mms1_hpca_oplus_number_density',
#  'mms1_hpca_oplus_ion_bulk_velocity',
#  'mms1_hpca_oplus_scalar_temperature',
#  'mms1_hpca_oplus_ion_pressure',
#  'mms1_hpca_oplus_temperature_tensor',
#  'mms1_hpca_B_GSE_spin_avg',
#  'mms1_hpca_B_GSM_spin_avg',
#  'mms1_hpca_hplus_ion_bulk_velocity_GSM',
#  'mms1_hpca_hplus_tperp',
#  'mms1_hpca_hplus_tparallel',
#  'mms1_hpca_hplus_vperp',
#  'mms1_hpca_hplus_vparallel',
#  'mms1_hpca_hplus_vperp_GSM',
#  'mms1_hpca_hplus_vparallel_GSM',
#  'mms1_hpca_heplus_ion_bulk_velocity_GSM',
#  'mms1_hpca_heplus_tperp',
#  'mms1_hpca_heplus_tparallel',
#  'mms1_hpca_heplus_vperp',
#  'mms1_hpca_heplus_vparallel',
#  'mms1_hpca_heplus_vperp_GSM',
#  'mms1_hpca_heplus_vparallel_GSM',
#  'mms1_hpca_heplusplus_ion_bulk_velocity_GSM',
#  'mms1_hpca_heplusplus_tperp',
#  'mms1_hpca_heplusplus_tparallel',
#  'mms1_hpca_heplusplus_vperp',
#  'mms1_hpca_heplusplus_vparallel',
#  'mms1_hpca_heplusplus_vperp_GSM',
#  'mms1_hpca_heplusplus_vparallel_GSM',
#  'mms1_hpca_oplus_ion_bulk_velocity_GSM',
#  'mms1_hpca_oplus_tperp',
#  'mms1_hpca_oplus_tparallel',
#  'mms1_hpca_oplus_vperp',
#  'mms1_hpca_oplus_vparallel',
#  'mms1_hpca_oplus_vperp_GSM',
#  'mms1_hpca_oplus_vparallel_GSM']

# %%
mms_part_slice2d(interpolation='2d', time='2023-03-24 07:07:33', instrument='fpi', species='i',rotation='be', data_rate='brst', erange=[0, 20000])
# Out:
# 18-Dec-25 14:36:38: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-dist, after sorting and filtering:
# 18-Dec-25 14:36:38: pydata/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:36:39: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:36:39: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:36:39: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:36:39: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:39: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:39: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:36:39: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:39: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:39: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:36:39: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:39: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:36:40: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-moms, after sorting and filtering:
# 18-Dec-25 14:36:40: pydata/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:36:40: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:36:40: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:36:40: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:36:40: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:40: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:40: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:36:40: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:40: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:40: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:36:40: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:36:40: Averaging mms1_dis_bulkv_gse_brst
# 18-Dec-25 14:36:40: Aligning slice plane to: be
# 18-Dec-25 14:36:40: Finished slice at 2023-03-24 07:07:32.858868

# %%
mms_part_slice2d(interpolation='2d', time='2023-03-24 07:07:55', instrument='fpi', species='i',rotation='bv', data_rate='brst', erange=[0, 20000])
# Out:
# 18-Dec-25 14:36:41: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-dist, after sorting and filtering:
# 18-Dec-25 14:36:41: pydata/mms1/fpi/brst/l2/dis-dist/2023/03/24/mms1_fpi_brst_l2_dis-dist_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:36:42: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:36:42: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:36:42: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:36:42: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:42: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:42: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:36:42: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:42: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:42: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:36:42: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:36:42: pydata/mms1/fgm/brst/l2/2023/03/24/mms1_fgm_brst_l2_20230324070453_v5.391.0.cdf
# 18-Dec-25 14:36:42: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-moms, after sorting and filtering:
# 18-Dec-25 14:36:42: pydata/mms1/fpi/brst/l2/dis-moms/2023/03/24/mms1_fpi_brst_l2_dis-moms_20230324070453_v3.4.0.cdf
# 18-Dec-25 14:36:43: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 14:36:43: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 14:36:43: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 14:36:43: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:43: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 14:36:43: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 14:36:43: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:43: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 14:36:43: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 14:36:43: Averaging mms1_fgm_b_gse_brst_l2_bvec
# 18-Dec-25 14:36:43: Averaging mms1_dis_bulkv_gse_brst
# 18-Dec-25 14:36:43: Aligning slice plane to: bv
# 18-Dec-25 14:36:43: Finished slice at 2023-03-24 07:07:54.909068

# %%
pyspedas.tplot( 'mms1_dis_bulkv_dbcs_fast')
