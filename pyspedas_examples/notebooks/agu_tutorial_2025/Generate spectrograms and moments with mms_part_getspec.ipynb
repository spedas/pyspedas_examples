# %% [markdown]
# This notebook shows how to use `mms_part_getspec` to generate particle spectrograms and moments from level 2 MMS FPI and HPCA velocity distribution data.

# %% [markdown]
# This command sets up the PySPEDAS environment when running in Google Colab.  You can skip it or comment it out if you're running this notebook in an environment that already has PySPEDAS installed.

# %%
# !pip install pyspedas
# Out:
# Requirement already satisfied: pyspedas in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (2.0.5)
# Requirement already satisfied: numpy>=1.20.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2.2.6)
# Requirement already satisfied: requests>=2.31.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2.32.5)
# Requirement already satisfied: geopack>=1.0.12 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.0.12)
# Requirement already satisfied: scipy>=1.11.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.16.3)
# Requirement already satisfied: cdflib>=1.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.3.6)
# Requirement already satisfied: spacepy>=0.5.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (0.7.0)
# Requirement already satisfied: cdasws>=1.7.24 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.8.11)
# Requirement already satisfied: netCDF4>=1.6.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.7.3)
# Requirement already satisfied: pywavelets>=1.4.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (1.9.0)
# Requirement already satisfied: astropy>=5.3.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (7.1.1)
# Requirement already satisfied: hapiclient>=0.2.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (0.2.6)
# Requirement already satisfied: fsspec>=2023.9.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2025.10.0)
# Requirement already satisfied: s3fs>=2023.9.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2025.10.0)
# Requirement already satisfied: aioboto3>=11.1.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (15.5.0)
# Requirement already satisfied: pandas>=2.0.3 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2.3.3)
# Requirement already satisfied: matplotlib>=3.6.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (3.10.7)
# Requirement already satisfied: xarray>=2023.7.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pyspedas) (2025.10.1)
# Requirement already satisfied: aiobotocore[boto3]==2.25.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aioboto3>=11.1.1->pyspedas) (2.25.1)
# Requirement already satisfied: aiofiles>=23.2.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aioboto3>=11.1.1->pyspedas) (25.1.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (0.13.0)
# Requirement already satisfied: botocore<1.40.62,>=1.40.46 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.40.61)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.17.3)
# Requirement already satisfied: boto3<1.40.62,>=1.40.46 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.40.61)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (0.2025.11.10.0.38.31)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from astropy>=5.3.1->pyspedas) (25.0)
# Requirement already satisfied: urllib3>=1.24.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from cdasws>=1.7.24->pyspedas) (2.5.0)
# Requirement already satisfied: isodate>=0.6.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from hapiclient>=0.2.2->pyspedas) (0.7.2)
# Requirement already satisfied: joblib in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from hapiclient>=0.2.2->pyspedas) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from matplotlib>=3.6.2->pyspedas) (3.2.5)
# Requirement already satisfied: cftime in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from netCDF4>=1.6.2->pyspedas) (1.6.4)
# Requirement already satisfied: certifi in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from netCDF4>=1.6.2->pyspedas) (2025.11.12)
# Requirement already satisfied: pytz>=2020.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pandas>=2.0.3->pyspedas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from pandas>=2.0.3->pyspedas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from requests>=2.31.0->pyspedas) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from requests>=2.31.0->pyspedas) (3.11)
# Requirement already satisfied: h5py>=2.10 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from spacepy>=0.5.0->pyspedas) (3.15.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp<4.0.0,>=3.9.2->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (4.15.0)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /Users/jwl/anaconda3/envs/pycharm_py312/lib/python3.12/site-packages (from boto3<1.40.62,>=1.40.46->aiobotocore[boto3]==2.25.1->aioboto3>=11.1.1->pyspedas) (0.14.0)

# %% [markdown]
# Get started by importing `mms_part_getspec`

# %%
from pyspedas.projects.mms import mms_part_getspec
from pyspedas import tplot

# %% [markdown]
# ### FPI spectrograms and moments
#
# Notes:
# - as with the load routines, most keywords have defaults, e.g., the instrument keyword defaults to 'fpi'
# - internal and external photoelectron corrections are applied to FPI electrons prior to generating the moments

# %%
mms_part_getspec(trange=['2015-10-16/13:05:40', '2015-10-16/13:06:10'], 
                 instrument='fpi',
                 data_rate='brst', 
                 probe=1, 
                 species='i', 
                 output=['phi', 'theta', 'energy', 'pa', 'gyro', 'moments'])
# Out:
# 18-Dec-25 13:50:17: Downloading mms1_fpi_brst_l2_dis-dist_20151016130524_v3.3.0.cdf to pydata/mms1/fpi/brst/l2/dis-dist/2015/10/16
# 18-Dec-25 13:50:21: Loading files for group: probe: 1, drate: brst, level: l2, datatype: dis-dist, after sorting and filtering:
# 18-Dec-25 13:50:21: pydata/mms1/fpi/brst/l2/dis-dist/2015/10/16/mms1_fpi_brst_l2_dis-dist_20151016130524_v3.3.0.cdf
# 18-Dec-25 13:50:22: The name mms1_dis_pitchangdist_lowen_brst is currently not in pyspedas
# 18-Dec-25 13:50:22: The name mms1_dis_pitchangdist_miden_brst is currently not in pyspedas
# 18-Dec-25 13:50:22: The name mms1_dis_pitchangdist_highen_brst is currently not in pyspedas
# 18-Dec-25 13:50:22: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 13:50:22: The name mms1_des_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 13:50:22: Problem reading the variable: mms1_des_compressionloss_brst_moms
# 18-Dec-25 13:50:22: The name mms1_dis_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 13:50:22: The name mms1_dis_compressionloss_brst_moms is currently not in pyspedas
# 18-Dec-25 13:50:22: Problem reading the variable: mms1_dis_compressionloss_brst_moms
# 18-Dec-25 13:50:22: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 13:50:22: The name mms1_des_compressionloss_brst_dist is currently not in pyspedas
# 18-Dec-25 13:50:22: Problem reading the variable: mms1_des_compressionloss_brst_dist
# 18-Dec-25 13:50:22: Downloading mms1_mec_srvy_l2_epht89q_20151016_v2.2.1.cdf to pydata/mms1/mec/srvy/l2/epht89q/2015/10
# 18-Dec-25 13:50:23: Loading files for group: probe: 1, drate: srvy, level: l2, datatype: epht89q, after sorting and filtering:
# 18-Dec-25 13:50:23: pydata/mms1/mec/srvy/l2/epht89q/2015/10/mms1_mec_srvy_l2_epht89q_20151016_v2.2.1.cdf
# 18-Dec-25 13:50:24: Downloading mms1_fgm_brst_l2_20151016130334_v4.18.1.cdf to pydata/mms1/fgm/brst/l2/2015/10/16
# 18-Dec-25 13:50:24: Downloading mms1_fgm_brst_l2_20151016130524_v4.18.1.cdf to pydata/mms1/fgm/brst/l2/2015/10/16
# 18-Dec-25 13:50:25: Loading files for group: probe: 1, drate: brst, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 13:50:25: pydata/mms1/fgm/brst/l2/2015/10/16/mms1_fgm_brst_l2_20151016130334_v4.18.1.cdf
# 18-Dec-25 13:50:25: pydata/mms1/fgm/brst/l2/2015/10/16/mms1_fgm_brst_l2_20151016130524_v4.18.1.cdf
# 18-Dec-25 13:50:25: Downloading mms1_edp_brst_l2_scpot_20151016130334_v2.4.0.cdf to pydata/mms1/edp/brst/l2/scpot/2015/10/16
# 18-Dec-25 13:50:29: Downloading mms1_edp_brst_l2_scpot_20151016130524_v2.4.0.cdf to pydata/mms1/edp/brst/l2/scpot/2015/10/16
# 18-Dec-25 13:50:35: Loading files for group: probe: 1, drate: brst, level: l2, datatype: scpot, after sorting and filtering:
# 18-Dec-25 13:50:35: pydata/mms1/edp/brst/l2/scpot/2015/10/16/mms1_edp_brst_l2_scpot_20151016130334_v2.4.0.cdf
# 18-Dec-25 13:50:35: pydata/mms1/edp/brst/l2/scpot/2015/10/16/mms1_edp_brst_l2_scpot_20151016130524_v2.4.0.cdf
# 18-Dec-25 13:50:36: ['gse', 'gei']
# 18-Dec-25 13:50:36: Running transformation: subgse2gei
# 18-Dec-25 13:50:36: Setting coordinate system for mms1_mec_r_gse
# 18-Dec-25 13:50:36: Output variable: mms1_mec_r_gse
# 18-Dec-25 13:50:36: tinterpol (linear) was applied to: mms1_fgm_b_gse_brst_l2_bvec_pgs_temp
# 18-Dec-25 13:50:36: tinterpol (linear) was applied to: mms1_mec_r_gse_pgs_temp
# 18-Dec-25 13:50:36: ['gei', 'gse']
# 18-Dec-25 13:50:36: Running transformation: subgei2gse
# 18-Dec-25 13:50:36: Setting coordinate system for mms1_mec_r_gse_pgs_temp
# 18-Dec-25 13:50:36: Output variable: mms1_mec_r_gse_pgs_temp
# 18-Dec-25 13:50:36: tinterpol (linear) was applied to: mms1_fgm_b_gse_brst_l2_bvec_pgs_temp
# 18-Dec-25 13:50:36: wildcard_expand: No match found for mms1_dis_bulkv_gse_brst
# 18-Dec-25 13:50:36: tinterpol error: No pytplot names were provided.
# 18-Dec-25 13:50:36: The name mms1_dis_bulkv_gse_brst_pgs_temp is currently not in pyspedas
# 18-Dec-25 13:50:36: tinterpol (linear) was applied to: mms1_edp_scpot_brst_l2_pgs_temp
# 18-Dec-25 13:50:36: ==================================================================================
# 18-Dec-25 13:50:36: WARNING:
# 18-Dec-25 13:50:36: Moments generated with mms_part_products may be missing several important
# corrections, including photoelectron removal and spacecraft potential.
# The official moments released by the instrument teams include these and
# are the scientific products that should be used for analysis.
# 18-Dec-25 13:50:36: ==================================================================================
# 18-Dec-25 13:50:46: mms1_dis_dist_brst is 7% done.
# 18-Dec-25 13:50:57: mms1_dis_dist_brst is 14% done.
# 18-Dec-25 13:51:07: mms1_dis_dist_brst is 20% done.
# 18-Dec-25 13:51:18: mms1_dis_dist_brst is 26% done.
# 18-Dec-25 13:51:29: mms1_dis_dist_brst is 32% done.
# 18-Dec-25 13:51:39: mms1_dis_dist_brst is 38% done.
# 18-Dec-25 13:51:50: mms1_dis_dist_brst is 43% done.
# 18-Dec-25 13:52:00: mms1_dis_dist_brst is 48% done.
# 18-Dec-25 13:52:10: mms1_dis_dist_brst is 54% done.
# 18-Dec-25 13:52:21: mms1_dis_dist_brst is 60% done.
# 18-Dec-25 13:52:32: mms1_dis_dist_brst is 66% done.
# 18-Dec-25 13:52:42: mms1_dis_dist_brst is 72% done.
# 18-Dec-25 13:52:52: mms1_dis_dist_brst is 77% done.
# 18-Dec-25 13:53:03: mms1_dis_dist_brst is 83% done.
# 18-Dec-25 13:53:13: mms1_dis_dist_brst is 89% done.
# 18-Dec-25 13:53:23: mms1_dis_dist_brst is 94% done.
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_density
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_flux
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_flux
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_eflux
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_eflux
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_qflux
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_qflux
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_mftens
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_mftens
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_velocity
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_velocity
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_ptens
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_ptens
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_ttens
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_vthermal
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_avgtemp
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_magt3
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_magt3
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_t3
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_t3
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_symm
# 18-Dec-25 13:53:34: Setting coordinate system for mms1_dis_dist_brst_symm
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_symm_theta
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_symm_phi
# 18-Dec-25 13:53:34: Setting units for mms1_dis_dist_brst_symm_ang
# 18-Dec-25 13:53:34: Finished; time to run: 196.9 seconds.
# ['mms1_dis_dist_brst_density',
#  'mms1_dis_dist_brst_flux',
#  'mms1_dis_dist_brst_eflux',
#  'mms1_dis_dist_brst_qflux',
#  'mms1_dis_dist_brst_mftens',
#  'mms1_dis_dist_brst_velocity',
#  'mms1_dis_dist_brst_ptens',
#  'mms1_dis_dist_brst_ttens',
#  'mms1_dis_dist_brst_vthermal',
#  'mms1_dis_dist_brst_avgtemp',
#  'mms1_dis_dist_brst_magt3',
#  'mms1_dis_dist_brst_t3',
#  'mms1_dis_dist_brst_symm',
#  'mms1_dis_dist_brst_symm_theta',
#  'mms1_dis_dist_brst_symm_phi',
#  'mms1_dis_dist_brst_symm_ang',
#  'mms1_dis_dist_brst_energy',
#  'mms1_dis_dist_brst_theta',
#  'mms1_dis_dist_brst_phi',
#  'mms1_dis_dist_brst_pa',
#  'mms1_dis_dist_brst_gyro']

# %%
tplot(['mms1_dis_dist_brst_energy', 'mms1_dis_dist_brst_density'])

# %% [markdown]
# ### HPCA spectrograms and moments

# %%
mms_part_getspec(trange=['2015-10-16/10:30', '2015-10-16/10:40'],
                 instrument='hpca',
                 probe=1, 
                 species='hplus', 
                 output=['phi', 'theta', 'energy', 'pa', 'gyro', 'moments'])
# Out:
# 18-Dec-25 14:17:33: Loading files for group: probe: 1, drate: srvy, level: l2, datatype: ion, after sorting and filtering:
# 18-Dec-25 14:17:33: pydata/mms1/hpca/srvy/l2/ion/2015/10/mms1_hpca_srvy_l2_ion_20151016060000_v4.1.0.cdf
# 18-Dec-25 14:17:35: Variable mms1_hpca_hplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:17:36: Variable mms1_hpca_heplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:17:38: Variable mms1_hpca_heplusplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:17:39: Variable mms1_hpca_oplus_data_quality has only 1 dimension (including time), but has a DEPEND_1 attribute. Removing attribute.
# 18-Dec-25 14:17:41: wildcard_expand: No match found for mms1*_number_density
# 18-Dec-25 14:17:41: wildcard_expand: No match found for mms1*_ion_bulk_velocity*
# 18-Dec-25 14:17:41: wildcard_expand: No match found for mms1*_scalar_temperature
# 18-Dec-25 14:17:41: Loading files for group: probe: 1, drate: srvy, level: l2, datatype: epht89q, after sorting and filtering:
# 18-Dec-25 14:17:41: pydata/mms1/mec/srvy/l2/epht89q/2015/10/mms1_mec_srvy_l2_epht89q_20151016_v2.2.1.cdf
# 18-Dec-25 14:17:41: Loading files for group: probe: 1, drate: srvy, level: l2, datatype: , after sorting and filtering:
# 18-Dec-25 14:17:41: pydata/mms1/fgm/srvy/l2/2015/10/mms1_fgm_srvy_l2_20151016_v4.18.0.cdf
# 18-Dec-25 14:17:44: Loading files for group: probe: 1, drate: fast, level: l2, datatype: scpot, after sorting and filtering:
# 18-Dec-25 14:17:44: pydata/mms1/edp/fast/l2/scpot/2015/10/mms1_edp_fast_l2_scpot_20151016000000_v2.7.0.cdf
# 18-Dec-25 14:17:45: ['gse', 'gei']
# 18-Dec-25 14:17:45: Running transformation: subgse2gei
# 18-Dec-25 14:17:45: Setting coordinate system for mms1_mec_r_gse
# 18-Dec-25 14:17:45: Output variable: mms1_mec_r_gse
# 18-Dec-25 14:17:45: tinterpol (linear) was applied to: mms1_fgm_b_gse_srvy_l2_bvec_pgs_temp
# 18-Dec-25 14:17:45: tinterpol (linear) was applied to: mms1_mec_r_gse_pgs_temp
# 18-Dec-25 14:17:45: ['gei', 'gse']
# 18-Dec-25 14:17:45: Running transformation: subgei2gse
# 18-Dec-25 14:17:45: Setting coordinate system for mms1_mec_r_gse_pgs_temp
# 18-Dec-25 14:17:45: Output variable: mms1_mec_r_gse_pgs_temp
# 18-Dec-25 14:17:45: tinterpol (linear) was applied to: mms1_fgm_b_gse_srvy_l2_bvec_pgs_temp
# 18-Dec-25 14:17:45: wildcard_expand: No match found for mms1_hpca_hplus_ion_bulk_velocity
# 18-Dec-25 14:17:45: tinterpol error: No pytplot names were provided.
# 18-Dec-25 14:17:45: The name mms1_hpca_hplus_ion_bulk_velocity_pgs_temp is currently not in pyspedas
# 18-Dec-25 14:17:45: tinterpol (linear) was applied to: mms1_edp_scpot_fast_l2_pgs_temp
# 18-Dec-25 14:17:45: ==================================================================================
# 18-Dec-25 14:17:45: WARNING:
# 18-Dec-25 14:17:45: Moments generated with mms_part_products may be missing several important
# corrections, including photoelectron removal and spacecraft potential.
# The official moments released by the instrument teams include these and
# are the scientific products that should be used for analysis.
# 18-Dec-25 14:17:45: ==================================================================================
# 18-Dec-25 14:17:56: mms1_hpca_hplus_phase_space_density is 5% done.
# 18-Dec-25 14:18:07: mms1_hpca_hplus_phase_space_density is 12% done.
# 18-Dec-25 14:18:18: mms1_hpca_hplus_phase_space_density is 19% done.
# 18-Dec-25 14:18:29: mms1_hpca_hplus_phase_space_density is 25% done.
# 18-Dec-25 14:18:41: mms1_hpca_hplus_phase_space_density is 32% done.
# 18-Dec-25 14:18:51: mms1_hpca_hplus_phase_space_density is 37% done.
# 18-Dec-25 14:19:04: mms1_hpca_hplus_phase_space_density is 44% done.
# 18-Dec-25 14:19:14: mms1_hpca_hplus_phase_space_density is 49% done.
# 18-Dec-25 14:19:25: mms1_hpca_hplus_phase_space_density is 54% done.
# 18-Dec-25 14:19:37: mms1_hpca_hplus_phase_space_density is 61% done.
# 18-Dec-25 14:19:49: mms1_hpca_hplus_phase_space_density is 68% done.
# 18-Dec-25 14:20:00: mms1_hpca_hplus_phase_space_density is 75% done.
# 18-Dec-25 14:20:11: mms1_hpca_hplus_phase_space_density is 80% done.
# 18-Dec-25 14:20:21: mms1_hpca_hplus_phase_space_density is 85% done.
# 18-Dec-25 14:20:32: mms1_hpca_hplus_phase_space_density is 90% done.
# 18-Dec-25 14:20:43: mms1_hpca_hplus_phase_space_density is 95% done.
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_density
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_flux
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_flux
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_eflux
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_eflux
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_qflux
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_qflux
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_mftens
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_mftens
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_velocity
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_velocity
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_ptens
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_ptens
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_ttens
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_vthermal
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_avgtemp
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_magt3
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_magt3
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_t3
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_t3
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_symm
# 18-Dec-25 14:20:55: Setting coordinate system for mms1_hpca_hplus_phase_space_density_symm
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_symm_theta
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_symm_phi
# 18-Dec-25 14:20:55: Setting units for mms1_hpca_hplus_phase_space_density_symm_ang
# 18-Dec-25 14:20:55: Finished; time to run: 201.7 seconds.
# ['mms1_hpca_hplus_phase_space_density_density',
#  'mms1_hpca_hplus_phase_space_density_flux',
#  'mms1_hpca_hplus_phase_space_density_eflux',
#  'mms1_hpca_hplus_phase_space_density_qflux',
#  'mms1_hpca_hplus_phase_space_density_mftens',
#  'mms1_hpca_hplus_phase_space_density_velocity',
#  'mms1_hpca_hplus_phase_space_density_ptens',
#  'mms1_hpca_hplus_phase_space_density_ttens',
#  'mms1_hpca_hplus_phase_space_density_vthermal',
#  'mms1_hpca_hplus_phase_space_density_avgtemp',
#  'mms1_hpca_hplus_phase_space_density_magt3',
#  'mms1_hpca_hplus_phase_space_density_t3',
#  'mms1_hpca_hplus_phase_space_density_symm',
#  'mms1_hpca_hplus_phase_space_density_symm_theta',
#  'mms1_hpca_hplus_phase_space_density_symm_phi',
#  'mms1_hpca_hplus_phase_space_density_symm_ang',
#  'mms1_hpca_hplus_phase_space_density_energy',
#  'mms1_hpca_hplus_phase_space_density_theta',
#  'mms1_hpca_hplus_phase_space_density_phi',
#  'mms1_hpca_hplus_phase_space_density_pa',
#  'mms1_hpca_hplus_phase_space_density_gyro']

# %%
tplot(['mms1_hpca_hplus_phase_space_density_energy', 
       'mms1_hpca_hplus_phase_space_density_density'])
