# %%
from pyspedas.mth5.load_fdsn import load_fdsn
import pytplot

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
load_fdsn(network="4P", station="ALW48", trange=['2015-06-22', '2015-06-24'], nodownload=True)
# Out:
# 2024-02-16T19:39:15.147753-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\work\Data\SPEDAS\mth5\4P_ALW48_20150622_20150624.h5

# %%
pytplot.tplot('fdsn_4P_ALW48')
